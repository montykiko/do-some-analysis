# %% [markdown]
# http://voc.****.com

# %%
import requests,json
import pandas as pd
from pandas import DataFrame

# %% [markdown]
# # 获取公司信息(ck)

# %%
url = 'http://47.97.23.18:3030/companyinfo/?date=2018-03-28'
#query = {'username': "yuyitest", 'password': "KismetFTW123"}
headers={'Content-Type':'applicaiont/json','charset':'utf-8',"Authorization": "Basic eXV5aXRlc3Q6S2lzbWV0RlRXMTIz"}
r = requests.get(url,headers=headers)
file = json.loads(r.text)
data = pd.DataFrame(file)
data
# Out:
#      companyid companyname  firstTime                               refresh  \
# 0   2586824491     牧申手机旗舰店          0  626c0e35-fd2d-4c22-9d93-2afc0e416f77
# 1   0431446977       咔咔旗舰店          0  c2a54411-f263-4606-af75-74a36a6deedd
# 2   9346949831     君问数码旗舰店          0  33510b61-4e46-4d00-944e-1782cfb36569
# 3   8920646282      CR9旗舰店          1  c2648e80-45a9-4080-9b50-5e5378ed902b
# 4   1083947253        None          0  cf7a72eb-978e-40ea-badf-ac8083e31e9d
# 5   8846183885        None          1  66e7d696-33f9-4d20-80a7-cb0ccba257a1
# 6   6478807960        None          0  0681da3c-9e5e-4ab3-b600-6ee7bb598cfe
# 7   3873378978        None          0  37fb54c4-721a-4f1e-8f42-64e11a0a67b3
# 8   1427300845        None          1  0f89b113-e2a8-4ec6-8d89-e9834f1efe33
# 9   1099618988        None          0  42e6113f-59a6-401a-bc41-fcd8237f5509
# 10  1192936160        None          0  0cf625f8-fdc8-4358-9f48-499a2afbb762
# ...

# %% [markdown]
# # 获取公司信息(dq)

# %%
def send_request():
    # waiters
    # POST http://47.96.187.248/jd/waiters

    try:
        response = requests.post(
            url="http://47.96.187.248/jd/waiters",
            headers={
                "Content-Type": "application/json; charset=utf-8",
            },
            data=json.dumps({
                "userid": "9346949831",
                "token": "09a4e57c-8a12-43fb-bac4-2877679b98d9"
            })
        )
        return json.loads(response.content)
        print('Response HTTP Status Code: {status_code}'.format(
            status_code=response.status_code))
        print('Response HTTP Response Body: {content}'.format(
            content=response.content))
    except requests.exceptions.RequestException:
        print('HTTP Request failed')
        
send_request()
# Out:
# {'info': {'shopName': '君问手机旗舰店',
#   'shopUrl': 'http://mall.jd.com/index-null.html',
#   'waiterCount': 38,
#   'waiterList': [{'leader': True,
#     'level': '接客客服',
#     'waiter': 'sq-moyang',
#     'yn': 1},
#    {'leader': False, 'level': '不接客客服', 'waiter': '售前-浪郁', 'yn': 1},
#    {'leader': False, 'level': '不接客客服', 'waiter': '售前-德玛', 'yn': 1},
#    {'leader': False, 'level': '接客客服', 'waiter': '售前-风暴', 'yn': 1},
#    {'leader': False, 'level': '接客客服', 'waiter': '售前-凌岚', 'yn': 1},
#    {'leader': False, 'level': '接客客服', 'waiter': '售前-欢欢', 'yn': 1},
#    {'leader': False, 'level': '不接客客服', 'waiter': '运营-布欧', 'yn': 1},
#    {'leader': False, 'level': '不接客客服', 'waiter': '售后-木尘', 'yn': 1},
#    {'leader': False, 'level': '不接客客服', 'waiter': '售后-晨风', 'yn': 1},
#    {'leader': False, 'level': '不接客客服', 'waiter': '售后-文丑', 'yn': 1},
#    {'leader': False, 'level': '不接客客服', 'waiter': '售后-惊羽', 'yn': 1},
#    {'leader': False, 'level': '不接客客服', 'waiter': '物流-纵晶', 'yn': 1},
# ...

# %%
#Cookies.set('yuyi_username', "2586824491");
